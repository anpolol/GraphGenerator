# %%
from scipy.stats import betabinom, beta
import matplotlib.pyplot as plt
import numpy as np

# %%
rv = betabinom(10,5,5)
x = np.arange(rv.ppf(0.01),
              rv.ppf(0.99))
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv.pmf(x), 'bo', ms=8, label='betabinom pmf')
ax.vlines(x, 0, rv.pmf(x), colors='b', lw=5, alpha=0.5)
plt.show()

# %%
rv = beta(7.5, 7.5)
samples = np.load('sample_03.npy')
hist = []

for attr in samples:
    for attr2 in samples:
        hist.append((np.dot(attr,attr2)+1)/2)

plt.hist(hist, bins=40,density=True,alpha=0.5, label = 'Retrieved')
plt.hist(np.random.normal(0.2, 0.04,500*500),bins=40,density=True,alpha=0.5,label = 'Desired')
plt.legend()
plt.show()
